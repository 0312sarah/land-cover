# %% [markdown]
# Notebook pour lancer des **entraînements depuis colab**

# %%
from google.colab import drive
drive.mount('/content/drive')

print("Données l'accès à votre drive")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
# !git clone https://github.com/0312sarah/land-cover.git

# %%
# %cd /content

# %%
print("Vérifier qu'il y a bien : \ndrive \nland_cover")
# !ls
# Out:
# LICENSE
# README.md
# data_visualization.ipynb
# framework
# infer_config.yaml
# notebook_for_colab.ipynb
# train_config.yaml

# %%
import os 
os.chdir('land_cover')
print(os.getcwd())
